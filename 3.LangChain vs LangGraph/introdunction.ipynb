# %% [markdown]
# ![alt text](31qyMKNB2RA-HD.jpg)

# %% [markdown]
# # <b>what we will achieve from this video

# %% [markdown]
# ![CampusX - LangChain Vs LangGraph Agentic AI using LangGraph Video 3 CampusX [31qyMKNB2RA - 1536x864 - 4m19s].png](<attachment:CampusX - LangChain Vs LangGraph Agentic AI using LangGraph Video 3 CampusX [31qyMKNB2RA - 1536x864 - 4m19s].png>)

# %% [markdown]
# # <b> what we have learn in LangChain Playlist

# %% [markdown]
# ![CampusX - LangChain Vs LangGraph Agentic AI using LangGraph Video 3 CampusX [31qyMKNB2RA - 1536x864 - 14m47s].png](<attachment:CampusX - LangChain Vs LangGraph Agentic AI using LangGraph Video 3 CampusX [31qyMKNB2RA - 1536x864 - 14m47s].png>)

# %% [markdown]
# ![CampusX - LangChain Vs LangGraph Agentic AI using LangGraph Video 3 CampusX [31qyMKNB2RA - 1536x864 - 12m08s].png](<attachment:CampusX - LangChain Vs LangGraph Agentic AI using LangGraph Video 3 CampusX [31qyMKNB2RA - 1536x864 - 12m08s].png>)

# %% [markdown]
# ![CampusX - LangChain Vs LangGraph Agentic AI using LangGraph Video 3 CampusX [31qyMKNB2RA - 1536x864 - 13m47s].png](<attachment:CampusX - LangChain Vs LangGraph Agentic AI using LangGraph Video 3 CampusX [31qyMKNB2RA - 1536x864 - 13m47s].png>)

# %% [markdown]
# ![CampusX - LangChain Vs LangGraph Agentic AI using LangGraph Video 3 CampusX [31qyMKNB2RA - 1536x864 - 14m27s].png](<attachment:CampusX - LangChain Vs LangGraph Agentic AI using LangGraph Video 3 CampusX [31qyMKNB2RA - 1536x864 - 14m27s].png>)

# %% [markdown]
# # <b> Difference between Workflows and Agent
#  read this is more detail on https://www.anthropic.com/engineering/building-effective-agents

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Example of workflow
# ![CampusX - LangChain Vs LangGraph Agentic AI using LangGraph Video 3 CampusX [31qyMKNB2RA - 1536x864 - 16m21s].png](<attachment:CampusX - LangChain Vs LangGraph Agentic AI using LangGraph Video 3 CampusX [31qyMKNB2RA - 1536x864 - 16m21s].png>)

# %% [markdown]
# <pre>
#
#
#
# </pre>

# %% [markdown]
# ## We will try to understand create this workflow and implement them using Langchain
