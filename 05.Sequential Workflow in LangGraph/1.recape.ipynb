# %% [markdown]
# ![CampusX - Sequential Workflows in LangGraph Agentic AI using LangGraph Video 5 CampusX [bAWujyAl1Kk - 1536x864 - 1m27s].png](<attachment:CampusX - Sequential Workflows in LangGraph Agentic AI using LangGraph Video 5 CampusX [bAWujyAl1Kk - 1536x864 - 1m27s].png>)
