# %% [markdown]
# # <b>AgenticAi Playlist

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![CampusX_-_Agentic_AI_using_LangGraph_New_Playlist_LangGraph_Tutorial_yC36gN-rqjo_-_1536x864_-_12m49s.png](attachment:CampusX_-_Agentic_AI_using_LangGraph_New_Playlist_LangGraph_Tutorial_yC36gN-rqjo_-_1536x864_-_12m49s.png)

# %% [markdown]
# ![CampusX_-_Agentic_AI_using_LangGraph_New_Playlist_LangGraph_Tutorial_yC36gN-rqjo_-_1536x864_-_14m42s.png](attachment:CampusX_-_Agentic_AI_using_LangGraph_New_Playlist_LangGraph_Tutorial_yC36gN-rqjo_-_1536x864_-_14m42s.png)

# %% [markdown]
# ![CampusX_-_Agentic_AI_using_LangGraph_New_Playlist_LangGraph_Tutorial_yC36gN-rqjo_-_1536x864_-_16m30s.png](attachment:CampusX_-_Agentic_AI_using_LangGraph_New_Playlist_LangGraph_Tutorial_yC36gN-rqjo_-_1536x864_-_16m30s.png)
